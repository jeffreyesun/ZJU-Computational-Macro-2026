# %% [markdown]
# # Lecture 1 — Introduction & Dynamic Modelling
# ## 第一讲 —— 导论与动态建模
#
# **Computational Methods for Heterogeneous-Agent Macro**
# **异质性主体宏观的计算方法**
# Jeffrey Sun
#
# This notebook is empty -- no code for lecture 1!
#
# 本笔记本为空——第一讲没有代码。
